# %%
import os, json, itertools, bisect, gc

from transformers import AutoModelForCausalLM, AutoTokenizer, AutoConfig, LLaMATokenizer
import transformers
import tensorflow as tf
from accelerate import Accelerator
import accelerate
import time
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os, json, itertools, bisect, gc
# ----> 3 from transformers import AutoModelForCausalLM, AutoTokenizer, AutoConfig, LLaMATokenizer
#       4 import transformers
#       5 import tensorflow as tf
#
# ImportError: cannot import name 'LLaMATokenizer' from 'transformers' (/Users/beto/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/transformers/__init__.py)

# %%
tokenizer = LLaMATokenizer.from_pretrained('chaoyi-wu/MedLLaMA_13B')
model = LLaMATokenizer.from_pretrained('chaoyi-wu/MedLLaMA_13B')
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'LlamaTokenizer'.
# The class this function is called from is 'LLaMATokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'LlamaTokenizer'.
# The class this function is called from is 'LLaMATokenizer'.

# %%
# question = "What are the symptoms of COVID-19?"

# # Encode the question
# encoded_question = tokenizer.encode_plus(question, return_tensors='pt')

# # Pass the encoded question to the model
# outputs = model(**encoded_question)

# %%
, 
)

# %%
generated = model.generate(inputs = batch["input_ids"], max_length=200, do_sample=True, top_k=50)
print("model predict: ", tokenizer.decode(generated[0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 generated = model.generate(inputs = batch["input_ids"], max_length=200, do_sample=True, top_k=50)
#       2 print("model predict: ", tokenizer.decode(generated[0]))
#
# AttributeError: 'LLaMATokenizer' object has no attribute 'generate'

# %%
tokenizer = LLaMATokenizer.from_pretrained('chaoyi-wu/MedLLaMA_13B')
model = LLaMATokenizer.from_pretrained('chaoyi-wu/MedLLaMA_13B')
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'LlamaTokenizer'.
# The class this function is called from is 'LLaMATokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'LlamaTokenizer'.
# The class this function is called from is 'LLaMATokenizer'.

# %%
sentence = 'Hello, doctor' 
batch = tokenizer(
            sentence,
            return_tensors="pt", 
            add_special_tokens=False
        )

# %%
with torch.no_grad():
    generated = model.generate(inputs = batch["input_ids"], max_length=200, do_sample=True, top_k=50)
    print('model predict: ',tokenizer.decode(generated[0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 2
#       1 with torch.no_grad():
# ----> 2     generated = model.generate(inputs = batch["input_ids"], max_length=200, do_sample=True, top_k=50)
#       3     print('model predict: ',tokenizer.decode(generated[0]))
#
# AttributeError: 'LLaMATokenizer' object has no attribute 'generate'

# %%
import transformers
import tensorflow
tokenizer = transformers.LlamaTokenizer.from_pretrained('chaoyi-wu/MedLLaMA_13B')
model = transformers.LlamaForCausalLM.from_pretrained('chaoyi-wu/MedLLaMA_13B')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import transformers
#       2 import tensorflow
# ----> 3 tokenizer = transformers.LlamaTokenizer.from_pretrained('chaoyi-wu/MedLLaMA_13B')
#       4 model = transformers.LlamaForCausalLM.from_pretrained('chaoyi-wu/MedLLaMA_13B')
#
# File ~/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/transformers/utils/import_utils.py:1117, in _LazyModule.__getattr__(self, name)
#    1115     value = getattr(module, name)
#    1116 else:
# -> 1117     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#    1119 setattr(self, name, value)
#    1120 return value
#
# AttributeError: module transformers has no attribute LlamaTokenizer

# %%
sentence = 'Hello, doctor' 
batch = tokenizer(
            sentence,
            return_tensors="pt", 
            add_special_tokens=False
        )
with torch.no_grad():
    generated = model.generate(inputs = batch["input_ids"], max_length=200, do_sample=True, top_k=50)
    print('model predict: ',tokenizer.decode(generated[0]))

# %% [markdown]
# # PMC LLAMA

# %%
import transformers
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, AutoConfig, LLaMATokenizer
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
tokenizer = transformers.LLaMATokenizer.from_pretrained('chaoyi-wu/PMC_LLAMA_7B')
model = transformers.AutoModelForCausalLM.from_pretrained('chaoyi-wu/PMC_LLAMA_7B')
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'LlamaTokenizer'.
# The class this function is called from is 'LLaMATokenizer'.
# ...
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ...

# %%
sentence = 'Hello, doctor' 
batch = tokenizer(
            sentence,
            return_tensors="pt", 
            add_special_tokens=False
        )

# %%
with torch.no_grad():
    generated = model.generate(inputs = batch["input_ids"], max_length=200, do_sample=True, top_k=50)
    print('model predict: ',tokenizer.decode(generated[0]))
# Out:
# /Users/beto/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/transformers/generation/utils.py:1201: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 with torch.no_grad():
# ----> 2     generated = model.generate(inputs = batch["input_ids"], max_length=200, do_sample=True, top_k=50)
#       3     print('model predict: ',tokenizer.decode(generated[0]))
#
# File ~/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
# ...

# %%
device = "cpu"

tokenizer = transformers.LlamaTokenizer.from_pretrained("decapoda-research/llama-7b-hf")
model = transformers.LlamaForCausalLM.from_pretrained("decapoda-research/llama-7b-hf").to(device)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 3
#       1 device = "cpu"
# ----> 3 tokenizer = transformers.LlamaTokenizer.from_pretrained("decapoda-research/llama-7b-hf")
#       4 model = transformers.LlamaForCausalLM.from_pretrained("decapoda-research/llama-7b-hf").to(device)
#
# File ~/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/transformers/utils/import_utils.py:1117, in _LazyModule.__getattr__(self, name)
#    1115     value = getattr(module, name)
#    1116 else:
# -> 1117     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#    1119 setattr(self, name, value)
#    1120 return value
#
# AttributeError: module transformers has no attribute LlamaTokenizer

# %%
import transformers

device = "cpu"

tokenizer = transformers.LlamaTokenizer.from_pretrained("decapoda-research/llama-7b-hf")
model = transformers.LlamaForCausalLM.from_pretrained("decapoda-research/llama-7b-hf").to(device)
# Out:
# ...
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'LLaMATokenizer'.
# The class this function is called from is 'LlamaTokenizer'.
# You are using the legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This means that tokens that come after special tokens will not be properly handled. We recommend you to read the related pull request available at https://github.com/huggingface/transformers/pull/24565
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 device = "cpu"
#       5 tokenizer = transformers.LlamaTokenizer.from_pretrained("decapoda-research/llama-7b-hf")
# ...

# %%
import transformers
import torch
tokenizer = transformers.LlamaTokenizer.from_pretrained('chaoyi-wu/PMC_LLAMA_7B')
model = transformers.LlamaForCausalLM.from_pretrained('chaoyi-wu/PMC_LLAMA_7B')
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
sentence = 'Hello, doctor' 
batch = tokenizer(
            sentence,
            return_tensors="pt", 
            add_special_tokens=False
        )

# %%
with torch.no_grad():
    generated = model.generate(inputs = batch["input_ids"], max_length=200, do_sample=True, top_k=50)
    print('model predict: ',tokenizer.decode(generated[0]))
# Out:
# /Users/beto/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 with torch.no_grad():
# ----> 2     generated = model.generate(inputs = batch["input_ids"], max_length=200, do_sample=True, top_k=50)
#       3     print('model predict: ',tokenizer.decode(generated[0]))
#
# File ~/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
# ...

# %%
import transformers

device = "mps"#"cpu"

tokenizer = transformers.LlamaTokenizer.from_pretrained("decapoda-research/llama-7b-hf")
model = transformers.LlamaForCausalLM.from_pretrained("decapoda-research/llama-7b-hf").to(device)
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'LLaMATokenizer'.
# The class this function is called from is 'LlamaTokenizer'.
# You are using the legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This means that tokens that come after special tokens will not be properly handled. We recommend you to read the related pull request available at https://github.com/huggingface/transformers/pull/24565
# Loading checkpoint shards:   0%|          | 0/33 [00:00<?, ?it/s]

# %%
batch = tokenizer(
    "The capital of Canada is",
    return_tensors="pt", 
    add_special_tokens=False
)

batch = {k: v.to(device) for k, v in batch.items()}
generated = model.generate(batch["input_ids"], max_length=100)
print(tokenizer.decode(generated[0]))
# Out:
# /Users/beto/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(

# %%
import transformers
import torch

device ="cpu"# "mps"#

tokenizer = transformers.LlamaTokenizer.from_pretrained('chaoyi-wu/MedLLaMA_13B')
model = transformers.LlamaForCausalLM.from_pretrained('chaoyi-wu/MedLLaMA_13B').to(device)
# Out:
# You are using the legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This means that tokens that come after special tokens will not be properly handled. We recommend you to read the related pull request available at https://github.com/huggingface/transformers/pull/24565
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
sentence = 'Hello, doctor' 
batch = tokenizer(
            sentence,
            return_tensors="pt", 
            add_special_tokens=False
        )
batch = {k: v.to(device) for k, v in batch.items()}

# %%
with torch.no_grad():
    generated = model.generate(inputs = batch["input_ids"], max_length=200, do_sample=True, top_k=50)
    print('model predict: ',tokenizer.decode(generated[0]))
# Out:
# /Users/beto/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 with torch.no_grad():
# ----> 2     generated = model.generate(inputs = batch["input_ids"], max_length=200, do_sample=True, top_k=50)
#       3     print('model predict: ',tokenizer.decode(generated[0]))
#
# File ~/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
# ...
