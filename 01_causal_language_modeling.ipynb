# %%
# https://huggingface.co/docs/transformers/tasks/language_modeling
# INSTALLING PYTHORCH FOR M2
# pip3 install --pre torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/nightly/cpu

# %%
from huggingface_hub import notebook_login
# better use:
# $ huggingface-cli login

# %% [markdown]
# # Promot collection

# %%
prompt_0 = "Somatic hypermutation allows the immune system to"
prompt_1 = "cancer in blood is caused by"
prompt_2 = "cheadache is by"
prompt_3 = "What could be the diagnosis for a black person aged 43 with bmi 30 smoker low wbc count and high platelet count with flu-like symptoms and a body temperature of 38 degree Celsius"
prompt_4 = "black 43 y.o, bmi 30, smoker, low wbc count, flu-like symptoms, temperature of 38?"

# %% [markdown]
# # BioGPT

# %%
num_prompts = 5

# %%
from transformers import  BioGptForCausalLM, AutoModel
from transformers import pipeline

model = BioGptForCausalLM.from_pretrained("microsoft/biogpt")
generator = pipeline("text-generation", model="microsoft/biogpt")

# %%
for i in range(num_prompts):
    print(generator(eval("prompt_"+str(i))))
# Out:
# /Users/beto/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/transformers/generation/utils.py:1369: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'generated_text': 'Somatic hypermutation allows the immune system to recognize and eliminate mutated self-antigens.'}]
# [{'generated_text': 'cancer in blood is caused by the presence of a circulating tumor cell (CTC).'}]
# Input length of input_ids is 40, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 26, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# ...

# %%
from transformers import Conversation

# %%
model = AutoModel.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
# available tasks are [
    # 'audio-classification', 
    # 'automatic-speech-recognition', 
    # 'conversational', 
    # 'depth-estimation', 
    # 'document-question-answering', 
    # 'feature-extraction', 
    # 'fill-mask', 
    # 'image-classification', 
    # 'image-segmentation', 
    # 'image-to-text', 
    # 'mask-generation', 
    # 'ner', 
    # 'object-detection', 
    # 'question-answering', 
    # 'sentiment-analysis', 
    # 'summarization', 
    # 'table-question-answering', 
    # 'text-classification', 
    # 'text-generation', 
    # 'text2text-generation', 
    # 'token-classification', 
    # 'translation', 
    # 'video-classification', 
    # 'visual-question-answering', 
    # 'vqa', 
    # 'zero-shot-audio-classification', 
    # 'zero-shot-classification', 
    # 'zero-shot-image-classification', 
    # 'zero-shot-object-detection', 
    # 'translation_XX_to_YY']"

pipe = pipeline("conversational", model="emilyalsentzer/Bio_ClinicalBERT")
# Out:
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`

# %%
conversation = Conversation("black 43 y.o, bmi 30, smoker, low wbc count, flu-like symptoms, temperature of 38?")

# %%
conversation = pipe(conversation)
conversation.generated_responses[-1]
# Out:
# ',,,,,,,,,,'

# %%
for i in range(num_prompts):
    print(pipe(eval("prompt_"+str(i))))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 for i in range(num_prompts):
# ----> 2     print(pipe(eval("prompt_"+str(i))))
#
# File ~/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/transformers/pipelines/conversational.py:243, in ConversationalPipeline.__call__(self, conversations, num_workers, **kwargs)
#     223 r"""
#     224 Generate responses for the conversation(s) given as inputs.
#     225
#    (...)
#     237     containing a new user input.
#     238 """
#     239 # XXX: num_workers==0 is required to be backward compatible
#     240 # Otherwise the threads will require a Conversation copy.
#     241 # This will definitely hinder performance on GPU, but has to be opted
#     242 # in because of this BC change.
# --> 243 outputs = super().__call__(conversations, num_workers=num_workers, **kwargs)
# ...

# %%
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'LLaMATokenizer'.
# The class this function is called from is 'LlamaTokenizer'.
# Loading /Users/beto/Documents/Projects/medLLM/ChatDoctor/pretrained/...
# gpu_count 0
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 load_model("/Users/beto/Documents/Projects/medLLM/ChatDoctor/pretrained/")
#
# Cell In[35], line 25, in load_model(model_name, eight_bit, device_map)
#      11 print('gpu_count', gpu_count)
#      13 tokenizer = transformers.LlamaTokenizer.from_pretrained(model_name)
#      14 model = transformers.LlamaForCausalLM.from_pretrained(
#      15     model_name,
# ...

# %%
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/transformers/modeling_utils.py:460, in load_state_dict(checkpoint_file)
#     459 try:
# --> 460     return torch.load(checkpoint_file, map_location="cpu")
#     461 except Exception as e:
#
# File ~/Documents/Projects/medLLM/venv/lib/python3.10/site-packages/torch/serialization.py:988, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     986     pickle_load_args['encoding'] = 'utf-8'
# --> 988 with _open_file_like(f, 'rb') as opened_file:
#     989     if _is_zipfile(opened_file):
#     990         # The zipfile reader is going to advance the current file position.
#     991         # If we want to actually tail call to torch.jit.load, we need to
# ...

# %%
import torch
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')
