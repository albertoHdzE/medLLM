# %%
from processing_answers import *

# %%
total_df = concat_all_results()
mathe_df = total_df[total_df["language"]=="Mathematica"]
# mathe_df

# %%
sequences = list(mathe_df["sequence"].values)
programs = list(mathe_df["GPT4_answer"].values)

# %%
for i in range(len(sequences)):
    print(no_compression_units(programs[i], sequences[i]))
# Out:
# 20.0
# 10.0
# 20.0
# 20.0
# 10.0
# 10.0
# 10.0
# 10.0
# 20.0
# 30.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 10.0
# 10.0
# 10.0
# 10.0
# 20.0
# 30.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 10.0
# 10.0
# 10.0
# 10.0
# 20.0
# 30.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 10.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 10.0
# 20.0
# 10.0
# 10.0
# 10.0
# 10.0
# 20.0
# 30.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 10.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 10.0
# 20.0
# 10.0
# 10.0
# 10.0
# 10.0
# 20.0
# 30.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# ...
